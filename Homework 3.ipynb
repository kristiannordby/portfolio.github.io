# %% [markdown]
# ### Introduction
# In this project, I relied on the libraries NLTK, Scikit Learn, and the counter function from the collections library. In this process, I first take in a document using the format `with open(r"___","r") as f:` `f.read()` to load assign the text in the file to a variable as a string. I then perform operations to clean the text to include only alphabetical/numeric values and tokenize it so I can then extract trigrams for each group of text messages (spam and not spam). In doing so, I can better understand common word sequences in spam texts compared to that of normal texts.

# %%
import nltk
from nltk.util import ngrams
from nltk import word_tokenize
from nltk.corpus import stopwords
from collections import Counter
from sklearn.feature_extraction.text import CountVectorizer

# %% [markdown]
# #### Loading the Data

# %%
with open(r"C:\Users\kristian.nordby\OneDrive - West Point\Desktop\AY 25-1\NLP\Homework 3\SMSSpamCollection.json",'r', encoding='utf-8') as f:
    text = f.read()

# %% [markdown]
# #### Cleaning data of stop words and punctuation

# %% [markdown]
# Splitting the different classificiations into groups: I split the plain text into a list by splitting on each line, then I seperate each text into groups based on classification of spam or ham.

# %%
text_lines = text.split('\n')
ham_texts=[]
spam_texts=[]
misc=[]
for line in text_lines:
    if line[:3]=='ham':
        ham_texts.append(line.replace('ham\t','').lower())
    elif line[:4]=='spam':
        spam_texts.append(line.replace('spam\t','').lower())
    else:
        misc.append(line) #This will reveal any lines that were not properly sorted into the right list by using ham\t or spam\t as the delimeter

# %% [markdown]
# Check to make sure that the `misc` list is empty. All lines should start with `ham\t` or `spam\t` and be placed in their proper list.

# %%
print(misc)
# Out:
# ['']

# %% [markdown]
# #### Extract N-Grams

# %% [markdown]
# I first load in common stopwords from the `nltk.corpus`. Common stopwords include: a, an, and, then, but, so, for, if. These words do not provide substance or a better understanding of conceptual differences between spam and non-spam text messages, so I exclude them from my working token sets, `clean_ham_tokens` and `clean_spam_tokens`. I then call the `ngrams()` function from `nltk.util` to extract each n-gram. Then, I use the `Counter()` function from collections to sort the n-grams based on their frequency in each list.

# %%
stopwords_list = list(stopwords.words('english'))
### Geeksforgeeks.org. Assistance given to the author, written explanation. Geeksforgeeks.org explained to me how to use nltk's stopwords function 
###     to gather all common english stop words into a list. West Point, NY 13SEP2024.

ham_tokens = word_tokenize(' '.join(ham_texts))
spam_tokens = word_tokenize(' '.join(spam_texts))

punctuation = r",......\n\t'!@;:<>{}\[\]-_=+-/\*#$%^&*()`~\?hamspam"
clean_ham_tokens = [i for i in ham_tokens if i not in punctuation]
clean_spam_tokens = [i for i in spam_tokens if i not in punctuation]

ham_n_grams = list(ngrams(clean_ham_tokens,2))
spam_n_grams = list(ngrams(clean_spam_tokens,2))

bigram_freq_ham = Counter(ham_n_grams)
bigram_freq_spam = Counter(spam_n_grams)

# %%
bigram_freq_ham
# Out:
# Counter({('i', "'m"): 384,
#          ('lt', 'gt'): 276,
#          ('are', 'you'): 176,
#          ('i', "'ll"): 168,
#          ('do', "n't"): 130,
#          ('i', 'will'): 104,
#          ('you', 'are'): 96,
#          ('i', 'have'): 94,
#          ('do', 'you'): 94,
#          ('if', 'you'): 92,
#          ('but', 'i'): 92,
#          ('it', "'s"): 92,
#          ('and', 'i'): 91,
#          ('i', 'was'): 86,
#          ('in', 'the'): 86,
#          ('want', 'to'): 79,
#          ('going', 'to'): 77,
#          ('i', 'can'): 71,
#          ('have', 'to'): 71,
#          ('sorry', 'i'): 68,
#          ('so', 'i'): 68,
#          ('to', 'be'): 66,
#          ('to', 'get'): 65,
#          ('i', "'ve"): 64,
#          ('when', 'you'): 62,
#          ('i', 'do'): 61,
#          ('on', 'the'): 61,
#          ('need', 'to'): 61,
#          ('ca', "n't"): 60,
#          ('gon', 'na'): 58,
#          ('when', 'i'): 58,
#          ('will', 'be'): 58,
#          ('if', 'u'): 58,
#          ('that', "'s"): 56,
#          ('call', 'me'): 56,
#          ('i', 'think'): 56,
#          ('for', 'the'): 55,
#          ('i', 'want'): 55,
#          ('i', 'need'): 55,
#          ('i', 'got'): 55,
#          ('you', 'know'): 54,
#          ('i', 'love'): 54,
#          ('to', 'do'): 51,
#          ('you', 'have'): 49,
#          ('you', "'re"): 49,
#          ('you', 'can'): 49,
#          ('to', 'you'): 49,
#          ('you', 'want'): 49,
#          ('you', 'i'): 48,
#          ('to', 'go'): 47,
#          ('can', 'you'): 47,
#          ('if', 'i'): 45,
#          ('did', "n't"): 44,
#          ('i', 'know'): 44,
#          ('see', 'you'): 44,
#          ('to', 'come'): 44,
#          ("'ll", 'call'): 43,
#          ('you', 'in'): 43,
#          ('my', 'love'): 42,
#          ('me', 'i'): 42,
#          ('is', 'the'): 42,
#          ('of', 'the'): 42,
#          ('now', 'i'): 41,
#          ('tell', 'me'): 41,
#          ('at', 'the'): 41,
#          ('that', 'i'): 41,
#          ('hope', 'you'): 41,
#          ('it', 'is'): 41,
#          ('do', 'it'): 40,
#          ('how', 'are'): 40,
#          ('the', 'way'): 39,
#          ('go', 'to'): 39,
#          ('call', 'later'): 39,
#          ('to', 'me'): 39,
#          ('did', 'you'): 38,
#          ('to', 'the'): 38,
#          ('love', 'you'): 37,
#          ("'m", 'not'): 37,
#          ('me', 'to'): 37,
#          ('r', 'u'): 37,
#          ('do', 'u'): 37,
#          ('you', 'get'): 36,
#          ('i', 'ca'): 35,
#          ('u', 'r'): 35,
#          ('come', 'to'): 35,
#          ('in', 'my'): 35,
#          ('to', 'see'): 34,
#          ('how', 'much'): 34,
#          ('me', 'know'): 34,
#          ('right', 'now'): 34,
#          ('ok', 'i'): 33,
#          ('i', 'just'): 33,
#          ('out', 'of'): 33,
#          ('miss', 'you'): 33,
#          ('this', 'is'): 33,
#          ('i', 'dont'): 33,
#          ('that', 'you'): 32,
#          ('let', 'me'): 32,
#          ('we', 'can'): 32,
#          ('take', 'care'): 32,
#          ('i', 'did'): 31,
#          ('for', 'me'): 31,
#          ('you', 'do'): 31,
#          ('good', 'morning'): 31,
#          ('is', 'not'): 30,
#          ('he', "'s"): 30,
#          ('i', 'miss'): 30,
#          ('it', 'was'): 30,
#          ("'m", 'in'): 30,
#          ('then', 'i'): 29,
#          ('on', 'my'): 29,
#          ('how', "'s"): 29,
#          ('you', 'and'): 29,
#          ('i', 'had'): 29,
#          ('with', 'the'): 28,
#          ('i', 'hope'): 28,
#          ('at', 'home'): 28,
#          ('wan', 'na'): 28,
#          ('i', 'cant'): 28,
#          ('u', 'wan'): 28,
#          ('have', 'great'): 27,
#          ('cos', 'i'): 27,
#          ('have', 'you'): 27,
#          ("'ll", 'be'): 27,
#          ('so', 'much'): 27,
#          ('with', 'you'): 26,
#          ('give', 'me'): 26,
#          ('me', 'when'): 26,
#          ('what', 'i'): 26,
#          ('wan', '2'): 26,
#          ('call', 'you'): 25,
#          ('when', 'u'): 25,
#          ('i', 'thk'): 25,
#          ('all', 'the'): 25,
#          ('there', "'s"): 24,
#          ('where', 'are'): 24,
#          ('u', 'can'): 24,
#          ('the', 'same'): 24,
#          ('i', 'get'): 24,
#          ('what', 'time'): 24,
#          ('able', 'to'): 24,
#          ('to', 'take'): 24,
#          ('should', 'i'): 24,
#          ('babe', 'i'): 24,
#          ("n't", 'have'): 23,
#          ('up', 'to'): 23,
#          ('is', 'it'): 23,
#          ('is', 'my'): 23,
#          ('did', 'u'): 23,
#          ('lt', 'decimal'): 23,
#          ('decimal', 'gt'): 23,
#          ('lor', 'i'): 23,
#          ('by', 'the'): 23,
#          ('new', 'year'): 23,
#          ('think', 'i'): 23,
#          ('with', 'me'): 22,
#          ('today', 'i'): 22,
#          ('i', 'go'): 22,
#          ('we', "'re"): 22,
#          ('do', 'have'): 22,
#          ('you', 'will'): 22,
#          ('what', 'are'): 22,
#          ('what', "'s"): 22,
#          ('pls', 'send'): 22,
#          ('you', 'still'): 22,
#          ('an', 'hour'): 22,
#          ('to', 'my'): 22,
#          ('ok', 'lor'): 22,
#          ('send', 'me'): 22,
#          ('went', 'to'): 22,
#          ('is', 'that'): 21,
#          ('not', 'sure'): 21,
#          ('trying', 'to'): 21,
#          ('need', 'you'): 21,
#          ('you', 'like'): 21,
#          ('it', 'i'): 21,
#          ('i', 'could'): 21,
#          ('you', 'were'): 21,
#          ('i', 'thought'): 21,
#          ('way', 'to'): 21,
#          ('be', 'in'): 21,
#          ('have', "n't"): 21,
#          ('is', 'there'): 21,
#          ('no', 'need'): 21,
#          ('think', 'of'): 21,
#          ('can', 'go'): 21,
#          ('you', 'guys'): 21,
#          ("'m", 'going'): 21,
#          ('or', 'something'): 21,
#          ('thanks', 'for'): 21,
#          ('what', 'you'): 20,
#          ('i', 'come'): 20,
#          ('to', 'buy'): 20,
#          ('text', 'me'): 20,
#          ('i', 'guess'): 20,
#          ('it', 'to'): 20,
#          ('yeah', 'i'): 20,
#          ('just', 'got'): 20,
#          ('of', 'you'): 20,
#          ('u', 'get'): 20,
#          ('i', 'went'): 20,
#          ('will', 'come'): 20,
#          ('thank', 'you'): 19,
#          ('wo', "n't"): 19,
#          ("''", 'i'): 19,
#          ('pick', 'up'): 19,
#          ('to', 'send'): 19,
#          ('to', 'make'): 19,
#          ('no', 'i'): 19,
#          ('waiting', 'for'): 19,
#          ('you', 'doing'): 19,
#          ('be', 'there'): 19,
#          ('you', 'got'): 19,
#          ('there', 'is'): 19,
#          ('you', 'to'): 19,
#          ('good', 'night'): 19,
#          ('with', 'my'): 19,
#          ('would', 'be'): 19,
#          ('should', 'be'): 19,
#          ('my', 'phone'): 19,
#          ('i', 'tot'): 19,
#          ('happy', 'new'): 19,
#          ('but', 'it'): 19,
#          ('try', 'to'): 19,
#          ('like', 'to'): 18,
#          ('k', 'i'): 18,
#          ('yes', 'i'): 18,
#          ('know', 'when'): 18,
#          ('and', 'you'): 18,
#          ('k', 'k'): 18,
#          ('hi', 'hi'): 18,
#          ('if', 'we'): 18,
#          ('we', 'have'): 18,
#          ('to', 'say'): 18,
#          ('can', 'i'): 18,
#          ('wat', 'time'): 18,
#          ('he', 'is'): 18,
#          ('you', 'at'): 18,
#          ('because', 'i'): 18,
#          ('have', 'good'): 18,
#          ('we', 'are'): 18,
#          ('had', 'to'): 18,
#          ('we', "'ll"): 18,
#          ('to', 'your'): 18,
#          ('to', 'sleep'): 18,
#          ('can', 'do'): 18,
#          ('she', "'s"): 18,
#          ('has', 'been'): 17,
#          ('i', 'wont'): 17,
#          ('and', 'he'): 17,
#          ('to', 'tell'): 17,
#          ('the', 'best'): 17,
#          ('know', 'what'): 17,
#          ('i', 'like'): 17,
#          ('the', 'first'): 17,
#          ('of', 'my'): 17,
#          ('and', 'the'): 17,
#          ('last', 'night'): 17,
#          ('i', 'might'): 17,
#          ('great', 'day'): 17,
#          ('like', 'that'): 17,
#          ("'s", 'the'): 17,
#          ('know', 'i'): 17,
#          ('in', 'town'): 17,
#          ('for', 'you'): 17,
#          ('to', 'talk'): 16,
#          ('tell', 'you'): 16,
#          ('in', 'bed'): 16,
#          ('for', 'your'): 16,
#          ('you', 'up'): 16,
#          ('2', 'go'): 16,
#          ('of', 'me'): 16,
#          ('my', 'parents'): 16,
#          ('well', 'i'): 16,
#          ('u', 'still'): 16,
#          ('i', 'in'): 16,
#          ('it', 'will'): 16,
#          ('you', 'should'): 16,
#          ('i', 'told'): 16,
#          ('have', 'nice'): 16,
#          ('the', 'world'): 16,
#          ('da', 'i'): 16,
#          ('me', 'the'): 16,
#          ('my', 'dear'): 16,
#          ('can', 'get'): 16,
#          ('i', 'not'): 16,
#          ('dont', 'know'): 16,
#          ("'m", 'gon'): 15,
#          ('does', "n't"): 15,
#          ('wanted', 'to'): 15,
#          ("n't", 'know'): 15,
#          ('to', 'pick'): 15,
#          ('on', 'your'): 15,
#          ('he', 'said'): 15,
#          ('and', 'that'): 15,
#          ('to', 'pay'): 15,
#          ('my', 'life'): 15,
#          ('so', 'that'): 15,
#          ('not', 'to'): 15,
#          ('i', 'should'): 15,
#          ('to', 'know'): 15,
#          ('in', 'touch'): 15,
#          ('be', 'able'): 15,
#          ('nice', 'day'): 15,
#          ('talk', 'to'): 15,
#          ('i', 'really'): 15,
#          ('the', 'time'): 15,
#          ('the', 'other'): 15,
#          ('the', 'phone'): 15,
#          ('i', 'wish'): 15,
#          ('wish', 'you'): 15,
#          ('in', 'few'): 15,
#          ('i', 'would'): 15,
#          ('how', 'goes'): 15,
#          ('send', 'you'): 15,
#          ('you', 'need'): 15,
#          ("'m", 'at'): 15,
#          ("''", '``'): 15,
#          ('at', 'all'): 14,
#          ('let', 'you'): 14,
#          ('like', 'lt'): 14,
#          ('for', 'lt'): 14,
#          ('in', 'meeting'): 14,
#          ('today', 'is'): 14,
#          ('you', 'later'): 14,
#          ('later', 'i'): 14,
#          ('as', 'i'): 14,
#          ('gud', 'ni8'): 14,
#          ('you', 'think'): 14,
#          ('ok.', 'i'): 14,
#          ('i', 'sent'): 14,
#          ('i', 'said'): 14,
#          ('wake', 'up'): 14,
#          ('take', 'it'): 14,
#          ('is', 'd'): 14,
#          ('i', 'feel'): 14,
#          ('that', 'is'): 14,
#          ('lot', 'of'): 14,
#          ('princess', 'i'): 14,
#          ('go', 'for'): 14,
#          ('shall', 'i'): 14,
#          ('the', 'sea'): 14,
#          ('but', 'you'): 14,
#          ('you', 'so'): 14,
#          ('4', 'me'): 14,
#          ('kind', 'of'): 14,
#          ('how', 'many'): 14,
#          ('4', 'dinner'): 14,
#          ('we', 'will'): 14,
#          ('back', 'to'): 14,
#          ('then', 'u'): 14,
#          ('u', 'doing'): 14,
#          ('to', 'work'): 14,
#          ('with', 'your'): 14,
#          ('u', 'dun'): 13,
#          ('na', 'be'): 13,
#          ('have', 'been'): 13,
#          ('love', 'i'): 13,
#          ('you', 'not'): 13,
#          ('you', 'just'): 13,
#          ('and', 'how'): 13,
#          ('you', 'my'): 13,
#          ("n't", 'you'): 13,
#          ('to', 'give'): 13,
#          ('where', 'you'): 13,
#          ('make', 'it'): 13,
#          ('dont', 'have'): 13,
#          ('know', 'you'): 13,
#          ('yup', 'i'): 13,
#          ('lots', 'of'): 13,
#          ('sir', 'i'): 13,
#          ('time', 'to'): 13,
#          ('will', 'you'): 13,
#          ("'s", 'my'): 13,
#          ('gud', 'mrng'): 13,
#          ('how', 'is'): 13,
#          ('me', 'if'): 13,
#          ('why', 'you'): 13,
#          ('u', 'up'): 13,
#          ('in', 'your'): 13,
#          ('good', 'afternoon'): 13,
#          ('that', 'day'): 13,
#          ('gt', 'min'): 13,
#          ('what', 'happen'): 13,
#          ('know', 'that'): 13,
#          ('to', 'meet'): 13,
#          ('to', 'ur'): 13,
#          ('you', 'going'): 13,
#          ('in', 'like'): 13,
#          ('love', 'u'): 13,
#          ('why', 'i'): 13,
#          ('you', "'ll"): 13,
#          ('time', 'u'): 13,
#          ('hope', 'your'): 13,
#          ('c', 'u'): 13,
#          ('up', 'and'): 13,
#          ('get', 'the'): 13,
#          ('at', 'lt'): 13,
#          ('it', 'and'): 13,
#          ('at', 'least'): 13,
#          ('ok', 'then'): 13,
#          ('name', 'of'): 13,
#          ("n't", 'think'): 12,
#          ('lor', 'u'): 12,
#          ('know', 'if'): 12,
#          ('but', 'we'): 12,
#          ('want', 'you'): 12,
#          ('time', 'you'): 12,
#          ('me', 'in'): 12,
#          ('find', 'out'): 12,
#          ('home', 'i'): 12,
#          ('to', 'all'): 12,
#          ('its', 'not'): 12,
#          ('of', 'that'): 12,
#          ('i', 'call'): 12,
#          ('got', 'ta'): 12,
#          ('what', 'is'): 12,
#          ('we', 'went'): 12,
#          ('me', 'that'): 12,
#          ('will', 'call'): 12,
#          ('who', 'is'): 12,
#          ('my', 'house'): 12,
#          ('which', 'is'): 12,
#          ('get', 'it'): 12,
#          ('my', 'sis'): 12,
#          ('is', 'your'): 12,
#          ('meet', 'you'): 12,
#          ('i', 'dun'): 12,
#          ('cant', 'pick'): 12,
#          ('pick', 'the'): 12,
#          ('phone', 'right'): 12,
#          ('now', 'pls'): 12,
#          ('send', 'message'): 12,
#          ('up', 'for'): 12,
#          ('go', 'out'): 12,
#          ('they', 'are'): 12,
#          ("'s", 'not'): 12,
#          ('is', 'in'): 12,
#          ('i', 'didnt'): 12,
#          ('of', 'your'): 12,
#          ('supposed', 'to'): 12,
#          ('wait', '4'): 12,
#          ('will', 'go'): 12,
#          ('happy', 'birthday'): 12,
#          ('from', 'you'): 12,
#          ('are', 'not'): 12,
#          ('me', '2'): 12,
#          ('this', 'week'): 12,
#          ('time', 'i'): 12,
#          ('have', 'any'): 12,
#          ('to', 'hear'): 12,
#          ('me', 'and'): 12,
#          ('u', 'know'): 12,
#          ('and', 'then'): 12,
#          ('in', 'lt'): 12,
#          ("'ll", 'text'): 12,
#          ('my', 'wife'): 12,
#          ('give', 'you'): 12,
#          ('up', 'at'): 12,
#          ('your', 'day'): 12,
#          ('from', 'the'): 12,
#          ('on', 'lt'): 12,
#          ('was', "n't"): 12,
#          ('dun', 'wan'): 12,
#          ('you', 'for'): 11,
#          ('about', 'me'): 11,
#          ('u', 'do'): 11,
#          ('first', 'time'): 11,
#          ('come', 'by'): 11,
#          ('this', 'to'): 11,
#          ('all', 'ur'): 11,
#          ('like', 'you'): 11,
#          ('you', 'call'): 11,
#          ('in', 'e'): 11,
#          ('and', 'have'): 11,
#          ('is', "n't"): 11,
#          ('going', 'for'): 11,
#          ('anyway', 'i'): 11,
#          ('4', 'lunch'): 11,
#          ('will', 'do'): 11,
#          ('for', 'that'): 11,
#          ('me', 'call'): 11,
#          ('time', 'of'): 11,
#          ('get', 'to'): 11,
#          ('you', 'you'): 11,
#          ('day', 'i'): 11,
#          ('you', "'ve"): 11,
#          ('if', 'she'): 11,
#          ('the', 'end'): 11,
#          ('will', 'get'): 11,
#          ('you', 'when'): 11,
#          ('when', 'are'): 11,
#          ('no', 'problem'): 11,
#          ('there', 'i'): 11,
#          ('u', 'want'): 11,
#          ('to', 'u'): 11,
#          ('on', 'sat'): 11,
#          ('to', 'ask'): 11,
#          ('your', 'call'): 11,
#          ('in', 'sch'): 11,
#          ('got', 'it'): 11,
#          ('me', 'at'): 11,
#          ('are', 'having'): 11,
#          ('lol', 'i'): 11,
#          ("''", 'good'): 11,
#          ('you', 'babe'): 11,
#          ('how', 'to'): 11,
#          ('but', 'not'): 11,
#          ('come', 'back'): 11,
#          ('the', 'day'): 11,
#          ("n't", 'get'): 11,
#          ('gud', 'nyt'): 11,
#          ('but', 'its'): 11,
#          ('me', 'my'): 11,
#          ('u', 'knw'): 11,
#          ('is', 'very'): 11,
#          ('x', 'x'): 11,
#          ("'ve", 'been'): 10,
#          ('i', '‘'): 10,
#          ('up', 'with'): 10,
#          ('feel', 'like'): 10,
#          ('my', 'car'): 10,
#          ('but', 'he'): 10,
#          ('on', 'this'): 10,
#          ('cool', 'i'): 10,
#          ('it', 'but'): 10,
#          ('see', 'u'): 10,
#          ('when', 'we'): 10,
#          ('my', 'birthday'): 10,
#          ('the', 'one'): 10,
#          ('too', 'much'): 10,
#          ('hope', 'u'): 10,
#          ('you', 'pls'): 10,
#          ('for', 'my'): 10,
#          ('me', 'so'): 10,
#          ('the', 'money'): 10,
#          ('my', 'friends'): 10,
#          ('end', 'of'): 10,
#          ('and', 'it'): 10,
#          ('my', 'boytoy'): 10,
#          ('you', 'tomorrow'): 10,
#          ('you', 'please'): 10,
#          ("'s", 'up'): 10,
#          ('you', 'had'): 10,
#          ('think', 'you'): 10,
#          ('only', 'i'): 10,
#          ('the', 'person'): 10,
#          ('have', 'the'): 10,
#          ('get', 'back'): 10,
#          ('up', '2'): 10,
#          ('u', 'have'): 10,
#          ('is', 'really'): 10,
#          ('i', "'d"): 10,
#          ('it', 'in'): 10,
#          ('or', 'i'): 10,
#          ('so', 'how'): 10,
#          ('how', 'come'): 10,
#          ('here', 'and'): 10,
#          ('care', 'of'): 10,
#          ('up', 'i'): 10,
#          ('sure', 'i'): 10,
#          ('you', 'could'): 10,
#          ('hey', 'i'): 10,
#          ('one', 'of'): 10,
#          ('the', 'most'): 10,
#          ('last', 'week'): 10,
#          ('watching', 'tv'): 10,
#          ('get', 'out'): 10,
#          ('me', 'up'): 10,
#          ('it', 'on'): 10,
#          ('dear', 'i'): 10,
#          ('and', 'send'): 10,
#          ('across', 'the'): 10,
#          ('be', 'here'): 10,
#          ('of', 'd'): 10,
#          ('my', 'hair'): 10,
#          ('do', 'the'): 10,
#          ('one', 'day'): 10,
#          ('this', 'morning'): 10,
#          ("'s", 'ok'): 10,
#          ('want', 'me'): 10,
#          ('ask', 'me'): 10,
#          ('good', 'to'): 10,
#          ('swing', 'by'): 10,
#          ('fine', 'i'): 10,
#          ('was', 'the'): 10,
#          ('my', 'dad'): 10,
#          ('wants', 'to'): 10,
#          ('we', 'go'): 10,
#          ('in', 'ur'): 10,
#          ('next', 'week'): 10,
#          ('tomorrow', 'i'): 10,
#          ('text', 'you'): 10,
#          ('one', 'can'): 10,
#          ('i', 'shall'): 10,
#          ('if', 'he'): 10,
#          ('gt', 'i'): 10,
#          ('do', 'i'): 10,
#          ('went', '2'): 10,
#          ('like', 'this'): 10,
#          ('be', 'the'): 10,
#          ('sweet', 'dreams'): 10,
#          ('the', 'lt'): 10,
#          ('me', 'do'): 10,
#          ('pls', 'do'): 10,
#          ('thing', 'i'): 10,
#          ('how', 'i'): 10,
#          ('in', 'da'): 10,
#          ('of', 'ur'): 10,
#          ('for', 'all'): 9,
#          ('your', 'friends'): 9,
#          ("n't", 'want'): 9,
#          ('u', 'feel'): 9,
#          ('i', 'finish'): 9,
#          ('way', 'i'): 9,
#          ('see', 'if'): 9,
#          ("n't", 'even'): 9,
#          ('lar', 'i'): 9,
#          ('can', 'call'): 9,
#          ('thats', 'cool'): 9,
#          ('you', 'with'): 9,
#          ('u', 'i'): 9,
#          ('up', 'on'): 9,
#          ('said', '``'): 9,
#          ('i', 'felt'): 9,
#          ('you', 'dont'): 9,
#          ('i', 'forgot'): 9,
#          ('i', 'saw'): 9,
#          ('out', 'i'): 9,
#          ('u', 'to'): 9,
#          ('give', 'u'): 9,
#          ("n't", 'be'): 9,
#          ('if', 'not'): 9,
#          ('the', 'new'): 9,
#          ('can', 'not'): 9,
#          ('so', 'what'): 9,
#          ('wen', 'u'): 9,
#          ('you', 'go'): 9,
#          ('that', 'time'): 9,
#          ('love', 'ya'): 9,
#          ('my', 'sister'): 9,
#          ('are', 'we'): 9,
#          ('gt', 'th'): 9,
#          ('to', 'have'): 9,
#          ('can', 'come'): 9,
#          ('good', 'day'): 9,
#          ('to', 'keep'): 9,
#          ('u', 'in'): 9,
#          ('we', 'could'): 9,
#          ('that', 'we'): 9,
#          ('love', 'how'): 9,
#          ('what', 'to'): 9,
#          ('my', 'friend'): 9,
#          ('thinking', 'of'): 9,
#          ('then', 'ü'): 9,
#          ('no', 'more'): 9,
#          ('to', 'him'): 9,
#          ('make', 'sure'): 9,
#          ('may', 'be'): 9,
#          ('we', 'do'): 9,
#          ('what', 'about'): 9,
#          ('i', 'ask'): 9,
#          ('if', 'it'): 9,
#          ('like', 'i'): 9,
#          ('i', 'wanted'): 9,
#          ('then', 'we'): 9,
#          ('wishing', 'you'): 9,
#          ('you', 'what'): 9,
#          ('it', 'up'): 9,
#          ('2', 'u'): 9,
#          ('you', 'did'): 9,
#          ('ready', 'to'): 9,
#          ('and', 'if'): 9,
#          ('your', 'phone'): 9,
#          ('when', 'someone'): 9,
#          ('what', 'do'): 9,
#          ('think', 'about'): 9,
#          ('ü', 'wan'): 9,
#          ('i', 'send'): 9,
#          ('know', 'why'): 9,
#          ('please', 'call'): 9,
#          ('convey', 'my'): 9,
#          ('i', 'late'): 9,
#          ('me', 'your'): 9,
#          ('wat', 'u'): 9,
#          ('is', 'ur'): 9,
#          ('at', 'my'): 9,
#          ('the', 'only'): 9,
#          ('how', 'was'): 9,
#          ("''", 'do'): 9,
#          ('the', 'house'): 9,
#          ('send', 'it'): 9,
#          ('come', 'up'): 9,
#          ('ü', 'all'): 9,
#          ('morning', 'i'): 9,
#          ('me', 'how'): 9,
#          ('going', '2'): 9,
#          ('so', 'you'): 9,
#          ('come', 'tomorrow'): 9,
#          ('hi', 'darlin'): 9,
#          ('you', 'see'): 9,
#          ('my', 'colleagues'): 9,
#          ('it', 'if'): 9,
#          ('get', 'there'): 9,
#          ('and', 'will'): 8,
#          ('meet', 'up'): 8,
#          ('to', 'eat'): 8,
#          ('the', 'bus'): 8,
#          ('you', 'feel'): 8,
#          ("'s", 'still'): 8,
#          ("'s", 'why'): 8,
#          ('up', 'in'): 8,
#          ('go', 'home'): 8,
#          ('i', 'see'): 8,
#          ('anything', 'lor'): 8,
#          ('you', "'d"): 8,
#          ('i', 'crave'): 8,
#          ('know', 'how'): 8,
#          ('in', 'class'): 8,
#          ("'m", 'sorry'): 8,
#          ('home', 'now'): 8,
#          ('you', 'how'): 8,
#          ('i', 'waiting'): 8,
#          ('looking', 'for'): 8,
#          ('need', '2'): 8,
#          ("'m", 'done'): 8,
#          ('all', 'my'): 8,
#          ('back', 'in'): 8,
#          ("'m", 'still'): 8,
#          ('do', 'that'): 8,
#          ('aight', 'i'): 8,
#          ('get', 'some'): 8,
#          ('to', 'her'): 8,
#          ('that', 'he'): 8,
#          ('i', 'going'): 8,
#          ('of', 'joy'): 8,
#          ('you', 'happy'): 8,
#          ('in', 'love'): 8,
#          ('go', '4'): 8,
#          ('call', 'u'): 8,
#          ("'ve", 'got'): 8,
#          ('when', 'the'): 8,
#          ('where', "'s"): 8,
#          ('not', 'i'): 8,
#          ('keep', 'in'): 8,
#          ('me', 'you'): 8,
#          ('sent', 'you'): 8,
#          ('now', 'so'): 8,
#          ('u', 'call'): 8,
#          ('like', 'dat'): 8,
#          ('dat', 'i'): 8,
#          ('ur', 'friends'): 8,
#          ("'m", 'always'): 8,
#          ('that', 'was'): 8,
#          ('thanx', '4'): 8,
#          ('late', 'i'): 8,
#          ('i', 'asked'): 8,
#          ('get', 'your'): 8,
#          ('lem', 'me'): 8,
#          ('come', 'in'): 8,
#          ('you', 'smile'): 8,
#          ('like', 'the'): 8,
#          ("'ll", 'see'): 8,
#          ('you', 'this'): 8,
#          ('miss', 'u'): 8,
#          ('the', 'last'): 8,
#          ('day', 'u'): 8,
#          ('from', 'your'): 8,
#          ('then', 'you'): 8,
#          ('where', 'u'): 8,
#          ('in', 'an'): 8,
#          ('leave', 'it'): 8,
#          ('now', 'u'): 8,
#          ('in', 'office'): 8,
#          ('your', 'ass'): 8,
#          ('god', 'i'): 8,
#          ('and', 'all'): 8,
#          ('there', 'are'): 8,
#          ('do', 'my'): 8,
#          ('goes', 'that'): 8,
#          ('from', 'across'): 8,
#          ('is', 'like'): 8,
#          ('much', 'i'): 8,
#          ('wot', 'u'): 8,
#          ('4', 'my'): 8,
#          ('you', 'about'): 8,
#          ('thk', 'i'): 8,
#          ('going', 'out'): 8,
#          ('of', 'this'): 8,
#          ('i', 'mean'): 8,
#          ('what', 'happened'): 8,
#          ('going', 'home'): 8,
#          ('is', 'lt'): 8,
#          ('cause', 'i'): 8,
#          ('is', 'this'): 8,
#          ('u', 'will'): 8,
#          ('u', 'dont'): 8,
#          ('get', 'up'): 8,
#          ('tot', 'u'): 8,
#          ('not', 'going'): 8,
#          ('x', "''"): 8,
#          ('gt', 'minutes'): 8,
#          ('4', 'ur'): 8,
#          ('its', 'just'): 8,
#          ('come', 'down'): 8,
#          ('but', 'the'): 8,
#          ('you', 'give'): 8,
#          ('no', 'da'): 8,
#          ('came', 'to'): 8,
#          ('things', 'are'): 8,
#          ('about', 'the'): 8,
#          ('she', 'said'): 8,
#          ('lor', 'but'): 8,
#          ('gt', 'mins'): 8,
#          ('in', 'life'): 8,
#          ('but', 'only'): 8,
#          ('my', 'heart'): 8,
#          ('wait', 'till'): 8,
#          ('can', 'be'): 8,
#          ('wish', 'u'): 8,
#          ('want', '2'): 8,
#          ('my', 'work'): 8,
#          ('she', 'is'): 8,
#          ('are', 'u'): 8,
#          ('wif', 'my'): 8,
#          ('as', 'usual'): 8,
#          ('night', 'and'): 8,
#          ('after', 'that'): 8,
#          ('of', 'u'): 8,
#          ('you', 'come'): 8,
#          ('its', 'ok'): 8,
#          ('my', 'way'): 8,
#          ('home', 'and'): 8,
#          ('``', 'i'): 8,
#          ('2', 'meet'): 8,
#          ('more', 'than'): 8,
#          ('ok', 'but'): 8,
#          ('about', 'smiling'): 8,
#          ('the', 'name'): 8,
#          ('pls', 'pls'): 8,
#          ('wat', 'r'): 8,
#          ('u', 'and'): 8,
#          ('joy', "'s"): 8,
#          ("'s", 'father'): 8,
#          ('that', 'one'): 8,
#          ('told', 'me'): 8,
#          ('the', 'next'): 8,
#          ('number', 'i'): 8,
#          ('i', 'missed'): 8,
#          ('i', 'tell'): 8,
#          ('home', 'in'): 8,
#          ('empty', 'without'): 8,
#          ('so', 'early'): 7,
#          ('u', 'c'): 7,
#          ('as', 'per'): 7,
#          ('as', 'your'): 7,
#          ('about', 'this'): 7,
#          ('the', 'right'): 7,
#          ('how', 'you'): 7,
#          ('u', 'finish'): 7,
#          ("'m", 'really'): 7,
#          ('you', 'make'): 7,
#          ("'m", 'back'): 7,
#          ('work', 'i'): 7,
#          ('all', 'that'): 7,
#          ("n't", 'go'): 7,
#          ('about', 'you'): 7,
#          ('look', 'at'): 7,
#          ('see', 'the'): 7,
#          ('going', 'on'): 7,
#          ("n't", 'do'): 7,
#          ('since', 'i'): 7,
#          ('you', 'always'): 7,
#          ('part', 'of'): 7,
#          ('day', "''"): 7,
#          ('this', 'month'): 7,
#          ('gt', 'or'): 7,
#          ('me', 'for'): 7,
#          ('loads', 'of'): 7,
#          ('right', 'i'): 7,
#          ('my', 'mom'): 7,
#          ('not', 'too'): 7,
#          ('me', '4'): 7,
#          ('after', 'lunch'): 7,
#          ('so', 'its'): 7,
#          ('my', 'world'): 7,
#          ("'m", 'so'): 7,
#          ('make', 'me'): 7,
#          ('can', 'make'): 7,
#          ('but', 'if'): 7,
#          ('sure', 'you'): 7,
#          ('ok', 'no'): 7,
#          ('give', 'it'): 7,
#          ('of', 'course'): 7,
#          ('so', 'dont'): 7,
#          ('to', 'call'): 7,
#          ('call', 'him'): 7,
#          ('have', 'it'): 7,
#          ('as', 'well'): 7,
#          ('me', 'not'): 7,
#          ('the', 'message'): 7,
#          ('have', 'no'): 7,
#          ('you', 'too'): 7,
#          ('might', 'have'): 7,
#          ('do', 'not'): 7,
#          ('help', 'you'): 7,
#          ("'re", 'not'): 7,
#          ('hurt', 'you'): 7,
#          ('figure', 'out'): 7,
#          ('and', 'happy'): 7,
#          ('much', 'you'): 7,
#          ('new', 'years'): 7,
#          ('there', 'if'): 7,
#          ('i', 'wake'): 7,
#          ('to', 'change'): 7,
#          ('be', 'good'): 7,
#          ('u', 'lot'): 7,
#          ('everything', 'is'): 7,
#          ('at', 'some'): 7,
#          ('some', 'point'): 7,
#          ('is', 'no'): 7,
#          ('``', 'hey'): 7,
#          ('xxx', "''"): 7,
#          ("'s", 'your'): 7,
#          ('how', 'about'): 7,
#          ('i', 'meant'): 7,
#          ('cant', 'wait'): 7,
#          ('for', 'it'): 7,
#          ('of', 'them'): 7,
#          ('can', 'ü'): 7,
#          ('come', 'out'): 7,
#          ("'s", 'in'): 7,
#          ('but', 'do'): 7,
#          ('give', 'her'): 7,
#          ('afternoon', 'my'): 7,
#          ('later', 'tonight'): 7,
#          ('just', 'to'): 7,
#          ('i', 'left'): 7,
#          ('msg', 'me'): 7,
#          ('love', 'it'): 7,
#          ('you', 'said'): 7,
#          ("'s", 'fine'): 7,
#          ('i', 'called'): 7,
#          ('for', 'an'): 7,
#          ('message', 'i'): 7,
#          ('not', 'having'): 7,
#          ('mind', 'if'): 7,
#          ('anything', 'to'): 7,
#          ('whatever', 'you'): 7,
#          ('any', 'way'): 7,
#          ('come', 'home'): 7,
#          ('r', 'ü'): 7,
#          ('said', "''"): 7,
#          ('all', 'night'): 7,
#          ('no', 'one'): 7,
#          ('someone', 'is'): 7,
#          ('i', 'wil'): 7,
#          ('up', 'the'): 7,
#          ('still', 'in'): 7,
#          ("''", 'ok'): 7,
#          ('lt', 'time'): 7,
#          ('time', 'gt'): 7,
#          ('bring', 'it'): 7,
#          ('be', 'around'): 7,
#          ('down', 'to'): 7,
#          ('in', 'this'): 7,
#          ('i', 'noe'): 7,
#          ('to', 'smoke'): 7,
#          ('in', 'i'): 7,
#          ('to', 'leave'): 7,
#          ('leave', 'for'): 7,
#          ('call', 'i'): 7,
#          ('will', 'give'): 7,
#          ('whenever', 'you'): 7,
#          ('in', 'it'): 7,
#          ('she', 'can'): 7,
#          ('and', 'see'): 7,
#          ('c', 'ü'): 7,
#          ('i', 'still'): 7,
#          ('u', 'noe'): 7,
#          ('feel', 'when'): 7,
#          ('in', 'd'): 7,
#          ('sorry', 'da'): 7,
#          ('what', 'u'): 7,
#          ('help', 'me'): 7,
#          ('but', 'no'): 7,
#          ('yeah', 'we'): 7,
#          ('that', 'much'): 7,
#          ('for', 'one'): 7,
#          ('gt', 'lt'): 7,
#          ('ur', 'home'): 7,
#          ('you', 'the'): 7,
#          ('one', 'who'): 7,
#          ('it', 'u'): 7,
#          ('ur', 'smile'): 7,
#          ('was', 'in'): 7,
#          ('other', 'day'): 7,
#          ('to', 'find'): 7,
#          ('us', 'to'): 7,
#          ('4', 'u'): 7,
#          ...})

# %%
bigram_freq_spam
# Out:
# Counter({('you', 'have'): 73,
#          ('have', 'won'): 54,
#          ('your', 'mobile'): 49,
#          ('to', 'claim'): 46,
#          ('please', 'call'): 45,
#          ('this', 'is'): 41,
#          ('to', 'contact'): 37,
#          ('you', 'are'): 36,
#          ('u', 'have'): 30,
#          ('stop', 'to'): 28,
#          ('cash', 'or'): 27,
#          ('po', 'box'): 27,
#          ('to', 'receive'): 25,
#          ('will', 'be'): 25,
#          ('£1000', 'cash'): 23,
#          ('guaranteed', 'call'): 23,
#          ('for', 'your'): 22,
#          ('prize', 'guaranteed'): 22,
#          ('selected', 'to'): 20,
#          ('contact', 'you'): 20,
#          ('urgent', 'your'): 20,
#          ('from', 'landline'): 20,
#          ('send', 'stop'): 20,
#          ('go', 'to'): 19,
#          ('to', '86688'): 19,
#          ('holiday', 'or'): 19,
#          ('attempt', 'to'): 19,
#          ('every', 'week'): 19,
#          ('to', '8007'): 19,
#          ('await', 'collection'): 19,
#          ('to', 'win'): 18,
#          ('c', "'s"): 18,
#          ('for', 'free'): 18,
#          ('call', 'now'): 18,
#          ('find', 'out'): 18,
#          ('out', 'who'): 18,
#          ('or', 'call'): 18,
#          ('from', 'land'): 18,
#          ('land', 'line'): 18,
#          ('to', 'no'): 17,
#          ('customer', 'service'): 17,
#          ('to', 'be'): 17,
#          ('valid', '12hrs'): 17,
#          ('2', 'claim'): 17,
#          ('nokia', 'to'): 17,
#          ('free', 'entry'): 16,
#          ('to', 'the'): 16,
#          ('the', 'latest'): 16,
#          ('the', 'word'): 16,
#          ('12hrs', 'only'): 16,
#          ('private', 'your'): 16,
#          ('account', 'statement'): 16,
#          ('statement', 'for'): 16,
#          ('call', 'mobileupd8'): 16,
#          ('is', 'the'): 16,
#          ('contact', 'u.'): 16,
#          ('had', 'your'): 15,
#          ('trying', 'to'): 15,
#          ('draw', 'shows'): 15,
#          ('identifier', 'code'): 15,
#          ('ur', 'mob'): 15,
#          ('txt', 'stop'): 15,
#          ('dating', 'service'): 15,
#          ('just', 'call'): 15,
#          ('chance', 'to'): 15,
#          ('the', '2nd'): 15,
#          ('do', 'you'): 15,
#          ('have', 'been'): 14,
#          ('free', 'on'): 14,
#          ('ur', 'awarded'): 14,
#          ('we', 'are'): 14,
#          ('are', 'trying'): 14,
#          ('shows', 'that'): 14,
#          ('that', 'you'): 14,
#          ('you', 'to'): 14,
#          ('reply', 'or'): 14,
#          ('to', 'stop'): 14,
#          ('line', 'claim'): 14,
#          ('to', 'collect'): 14,
#          ('2nd', 'attempt'): 14,
#          ('just', 'txt'): 14,
#          ('tell', 'ur'): 14,
#          ('claim', 'call'): 13,
#          ('free', 'call'): 13,
#          ('in', 'the'): 13,
#          ('if', 'you'): 13,
#          ('tried', 'to'): 13,
#          ('won', 'guaranteed'): 13,
#          ('or', '£5000'): 13,
#          ('call', 'from'): 13,
#          ('waiting', 'for'): 13,
#          ('txt', 'nokia'): 13,
#          ('to', '87066'): 13,
#          ('your', 'phone'): 13,
#          ('has', 'been'): 13,
#          ('claim', 'ur'): 13,
#          ('your', '2003'): 13,
#          ('2003', 'account'): 13,
#          ('week', 'just'): 13,
#          ('claim', 'code'): 12,
#          ('the', 'new'): 12,
#          ('4', 'free'): 12,
#          ('guaranteed', '£1000'): 12,
#          ('caller', 'prize'): 12,
#          ('for', 'you'): 12,
#          ('ur', 'mobile'): 12,
#          ('urgent', 'we'): 12,
#          ('u', 'can'): 12,
#          ('camcorder', 'reply'): 12,
#          ('double', 'mins'): 12,
#          ('08000839402', 'or'): 12,
#          ('is', 'your'): 12,
#          ('half', 'price'): 12,
#          ('our', 'dating'): 12,
#          ('£2000', 'prize'): 12,
#          ('shows', '800'): 12,
#          ('800', 'un-redeemed'): 12,
#          ('points', 'call'): 12,
#          ('opt', 'out'): 12,
#          ('4', 'ur'): 12,
#          ('ur', 'mates'): 12,
#          ('chat', 'to'): 12,
#          ('per', 'min'): 12,
#          ('reply', 'to'): 11,
#          ('call', 'our'): 11,
#          ('our', 'customer'): 11,
#          ('bonus', 'caller'): 11,
#          ('is', 'our'): 11,
#          ('contact', 'u'): 11,
#          ('are', 'selected'): 11,
#          ('if', 'u'): 11,
#          ('the', 'uk'): 11,
#          ('reply', 'stop'): 11,
#          ('call', '08000930705'): 11,
#          ('now', 'send'): 11,
#          ('on', '08000839402'): 11,
#          ('line', 'rental'): 11,
#          ('mobile', 'number'): 11,
#          ('won', 'the'): 11,
#          ('to', 'your'): 11,
#          ('every', 'wk'): 11,
#          ('1st', 'week'): 11,
#          ('tone', '4'): 11,
#          ('and', 'tell'): 11,
#          ('you', 'want'): 11,
#          ('we', 'have'): 11,
#          ('do', "n't"): 11,
#          ("'s", 'apply'): 10,
#          ('as', 'valued'): 10,
#          ('thanks', 'for'): 10,
#          ('awarded', 'with'): 10,
#          ('service', 'representative'): 10,
#          ('representative', 'on'): 10,
#          ('speak', 'to'): 10,
#          ('to', 'live'): 10,
#          ('live', 'operator'): 10,
#          ('prize', 'on'): 10,
#          ('u', 'know'): 10,
#          ('have', 'secret'): 10,
#          ('secret', 'admirer'): 10,
#          ('reveal', 'who'): 10,
#          ('who', 'thinks'): 10,
#          ('music', 'to'): 10,
#          ('claim', 'your'): 10,
#          ('on', 'orange'): 10,
#          ('mobileupd8', 'on'): 10,
#          ('customer', 'services'): 10,
#          ('free', 'text'): 10,
#          ('free', 'for'): 10,
#          ('prize', 'to'): 10,
#          ('new', 'video'): 10,
#          ('£350', 'award'): 10,
#          ('ts', 'cs'): 10,
#          ('national', 'rate'): 10,
#          ('anytime', 'any'): 10,
#          ('any', 'network'): 10,
#          ('network', 'mins'): 10,
#          ('complimentary', '4'): 10,
#          ('cash', 'await'): 10,
#          ('sae', 'cs'): 10,
#          ('wan', 'na'): 10,
#          ('2', 'contact'): 10,
#          ('of', 'the'): 10,
#          ('to', 'get'): 10,
#          ('is', 'easy'): 10,
#          ('want', 'new'): 10,
#          ('to', 'update'): 9,
#          ('we', 'tried'): 9,
#          ('you', 're'): 9,
#          ('are', 'awarded'): 9,
#          ('only', '150ppm'): 9,
#          ('on', 'ur'): 9,
#          ('who', 'is'): 9,
#          ('entry', '2'): 9,
#          ('draw', 'txt'): 9,
#          ('txt', 'music'): 9,
#          ('750', 'anytime'): 9,
#          ('text', 'stop'): 9,
#          ('on', 'your'): 9,
#          ('is', 'free'): 9,
#          ('500', 'pounds'): 9,
#          ('only', '150p/msg'): 9,
#          ('you', 'can'): 9,
#          ('to', 'find'): 9,
#          ('who', 'it'): 9,
#          ('number', 'has'): 9,
#          ('been', 'awarded'): 9,
#          ('collect', 'your'): 9,
#          ('you', 'call'): 9,
#          ('un-redeemed', 's.'): 9,
#          ('s.', 'i.'): 9,
#          ('i.', 'm.'): 9,
#          ('m.', 'points'): 9,
#          ('stop', 'texts'): 9,
#          ('wk', 'txt'): 9,
#          ('nokia', 'tone'): 9,
#          ('to', 'opt'): 9,
#          ('from', 'your'): 9,
#          ('landline', 'your'): 9,
#          ('todays', 'draw'): 9,
#          ('mob', 'every'): 9,
#          ('take', 'part'): 9,
#          ('now', 'and'): 8,
#          ('entitled', 'to'): 8,
#          ('update', 'to'): 8,
#          ('latest', 'colour'): 8,
#          ('in', 'our'): 8,
#          ('be', 'charged'): 8,
#          ('re', 'your'): 8,
#          ('to', 'our'): 8,
#          ('free', 'camcorder'): 8,
#          ('for', 'delivery'): 8,
#          ('yours', 'call'): 8,
#          ('prize', 'call'): 8,
#          ('as', 'you'): 8,
#          ('£5000', 'prize'): 8,
#          ('been', 'specially'): 8,
#          ('specially', 'selected'): 8,
#          ('mobile', 'no'): 8,
#          ('numbers', 'ending'): 8,
#          ('join', 'the'): 8,
#          ('i', "'m"): 8,
#          ('reply', 'with'): 8,
#          ('admirer', 'who'): 8,
#          ('is', 'looking'): 8,
#          ('looking', '2'): 8,
#          ('2', 'make'): 8,
#          ('make', 'contact'): 8,
#          ('contact', 'with'): 8,
#          ('with', 'u-find'): 8,
#          ('u-find', 'out'): 8,
#          ('who', 'they'): 8,
#          ('they', 'r'): 8,
#          ('r', 'reveal'): 8,
#          ('thinks', 'ur'): 8,
#          ('ur', 'so'): 8,
#          ('so', 'special-call'): 8,
#          ('special-call', 'on'): 8,
#          ('get', 'the'): 8,
#          ('this', 'message'): 8,
#          ('camera', 'phones'): 8,
#          ('just', 'text'): 8,
#          ('it', 'is'): 8,
#          ('call', 'free'): 8,
#          ('your', '4'): 8,
#          ('with', 'the'): 8,
#          ('txt', 'word'): 8,
#          ('text', 'yes'): 8,
#          ('offers', 'mobile'): 8,
#          ('video', 'phone'): 8,
#          ('this', 'msg'): 8,
#          ('there', 'is'): 8,
#          ('or', '£2000'): 8,
#          ('2', 'stop'): 8,
#          ('gift', 'vouchers'): 8,
#          ('£100', 'weekly'): 8,
#          ('chance', '2'): 8,
#          ('collection', 'sae'): 8,
#          ('texts', 'call'): 8,
#          ('call', '08712460324'): 8,
#          ('u.', 'todays'): 8,
#          ('4', 'chance'): 8,
#          ('digital', 'camera'): 8,
#          ('new', 'nokia'): 8,
#          ('prize', '2'): 8,
#          ('claim', 'is'): 8,
#          ('only', '10p'): 8,
#          ('10p', 'per'): 8,
#          ('the', 'mobile'): 7,
#          ('txt', 'the'): 7,
#          ('to', '87077'): 7,
#          ('your', 'reply'): 7,
#          ('delivery', 'tomorrow'): 7,
#          ('your', 'free'): 7,
#          ('our', 'final'): 7,
#          ('2', 'ur'): 7,
#          ('uk', "'s"): 7,
#          ('per', 'msg'): 7,
#          ('stop', 'send'): 7,
#          ('to', '62468'): 7,
#          ('from', 'only'): 7,
#          ('congratulations', 'ur'): 7,
#          ('this', 'week'): 7,
#          ('mobile', 'for'): 7,
#          ('per', 'minute'): 7,
#          ('cash-balance', 'is'): 7,
#          ('is', 'currently'): 7,
#          ('to', 'maximize'): 7,
#          ('maximize', 'ur'): 7,
#          ('ur', 'cash-in'): 7,
#          ('cash-in', 'now'): 7,
#          ('with', '£2000'): 7,
#          ('claim', '3030.'): 7,
#          ('3030.', 'valid'): 7,
#          ('tenerife', 'holiday'): 7,
#          ('award', 'call'): 7,
#          ('to', 'this'): 7,
#          ('4', 'more'): 7,
#          ('£2,000', 'bonus'): 7,
#          ('ur', '£150'): 7,
#          ('£150', 'worth'): 7,
#          ('worth', 'of'): 7,
#          ('of', 'discount'): 7,
#          ('to', '85023'): 7,
#          ('85023', 'now'): 7,
#          ('mobile', 'cs'): 7,
#          ('or', 'reply'): 7,
#          ('shopping', 'spree'): 7,
#          ('this', 'weeks'): 7,
#          ('for', '1st'): 7,
#          ('week', 'no1'): 7,
#          ('no1', 'nokia'): 7,
#          ('get', 'txting'): 7,
#          ('txting', 'and'): 7,
#          ('pobox', '36504'): 7,
#          ('weekly', 'draw'): 7,
#          ('price', 'line'): 7,
#          ('you', 'know'): 7,
#          ('2', 'win'): 7,
#          ('win', '£100'): 7,
#          ('txt', 'chat'): 7,
#          ('log', 'onto'): 7,
#          ('have', '1'): 7,
#          ('1', 'new'): 7,
#          ('just', '20p'): 7,
#          ('20p', 'per'): 7,
#          ('min', 'ntt'): 7,
#          ('ntt', 'ltd'): 7,
#          ('ltd', 'po'): 7,
#          ('box', '1327'): 7,
#          ('1327', 'croydon'): 7,
#          ('croydon', 'cr9'): 7,
#          ('cr9', '5wb'): 7,
#          ('5wb', '0870'): 7,
#          ('for', 'the'): 7,
#          ('now', 'only'): 7,
#          ('urgent', 'please'): 7,
#          ('costa', 'del'): 7,
#          ('del', 'sol'): 7,
#          ('sol', 'holiday'): 7,
#          ('customer', 'you'): 6,
#          ('£900', 'prize'): 6,
#          ('u', 'r'): 6,
#          ('call', 'the'): 6,
#          ('mobile', 'update'): 6,
#          ('reply', 'hl'): 6,
#          ('dont', 'miss'): 6,
#          ('mobile', 'will'): 6,
#          ('by', 'replying'): 6,
#          ('08000930705', 'for'): 6,
#          ('your', 'mob'): 6,
#          ('2', 'receive'): 6,
#          ('receive', '£1000'): 6,
#          ('award', 'if'): 6,
#          ('to', 'end'): 6,
#          ('is', 'inviting'): 6,
#          ('inviting', 'you'): 6,
#          ('friend', 'reply'): 6,
#          ('stop', 'frnd'): 6,
#          ('frnd', 'to'): 6,
#          ('of', 'cd'): 6,
#          ('our', 'offer'): 6,
#          ('offer', 'of'): 6,
#          ('to', 'unsubscribe'): 6,
#          ('more', 'info'): 6,
#          ('colour', 'camera'): 6,
#          ('for', 'only'): 6,
#          ('ur', 'cash-balance'): 6,
#          ('currently', '500'): 6,
#          ('pounds', 'to'): 6,
#          ('86688', 'only'): 6,
#          ('latest', 'motorola'): 6,
#          ('your', 'ringtone'): 6,
#          ('ringtone', 'order'): 6,
#          ('per', 'week'): 6,
#          ('or', 'text'): 6,
#          ('is', 'call'): 6,
#          ('4', 'tenerife'): 6,
#          ('500', 'free'): 6,
#          ('40gb', 'ipod'): 6,
#          ('discount', 'vouchers'): 6,
#          ('yes', 'to'): 6,
#          ('now', 'savamob'): 6,
#          ('your', 'tone'): 6,
#          ("'s", 'c'): 6,
#          ('cs', 'apply'): 6,
#          ('service', 'announcement'): 6,
#          ('receive', '£350'): 6,
#          ('dear', 'voucher'): 6,
#          ('voucher', 'holder'): 6,
#          ('for', 'shows'): 6,
#          ('is', 'an'): 6,
#          ('mates', 'www.getzed.co.uk'): 6,
#          ('www.getzed.co.uk', 'pobox'): 6,
#          ('36504', 'w45wq'): 6,
#          ('your', 'complimentary'): 6,
#          ('100', 'free'): 6,
#          ('chat', 'now'): 6,
#          ('won', '£800'): 6,
#          ('£800', 'prize'): 6,
#          ('now', 'all'): 6,
#          ("'ve", 'been'): 6,
#          ('final', 'attempt'): 6,
#          ('awarded', 'sipix'): 6,
#          ('sipix', 'digital'): 6,
#          ('camera', 'call'): 6,
#          ('landline', 'delivery'): 6,
#          ('delivery', 'within'): 6,
#          ('draw', '4'): 6,
#          ('important', 'information'): 6,
#          ('today', 'is'): 6,
#          ('lucky', 'day'): 6,
#          ('out', 'why'): 6,
#          ('why', 'log'): 6,
#          ('onto', 'http'): 6,
#          ('http', '//www.urawinner.com'): 6,
#          ('//www.urawinner.com', 'there'): 6,
#          ("n't", 'know'): 6,
#          ('86688', 'now'): 6,
#          ('good', 'luck'): 6,
#          ('weekly', 'comp'): 6,
#          ('is', 'now'): 6,
#          ('fantasies', 'call'): 6,
#          ('now', '08707509020'): 6,
#          ('08707509020', 'just'): 6,
#          ('£250', 'cash'): 6,
#          ('cash', 'every'): 6,
#          ('rate', 'call'): 6,
#          ('what', 'you'): 6,
#          ('when', 'you'): 6,
#          ('to', '86021'): 6,
#          ('86021', 'now'): 6,
#          ('2nd', 'time'): 6,
#          ('time', 'we'): 6,
#          ('have', 'tried'): 6,
#          ('u.', 'u'): 6,
#          ('4', 'costa'): 6,
#          ('£5000', 'await'): 6,
#          ('collection', 'call'): 6,
#          ('call', '09050090044'): 6,
#          ('09050090044', 'now'): 6,
#          ('now', 'toclaim'): 6,
#          ('toclaim', 'sae'): 6,
#          ('pobox334', 'stockport'): 6,
#          ('stockport', 'sk38xh'): 6,
#          ('sk38xh', 'cost£1.50/pm'): 6,
#          ('cost£1.50/pm', 'max10mins'): 6,
#          ('easy', 'just'): 6,
#          ('to', 'you'): 6,
#          ('orange', 'tariffs'): 6,
#          ('entry', 'in'): 5,
#          ('in', '2'): 5,
#          ('std', 'txt'): 5,
#          ('txt', 'rate'): 5,
#          ('rate', 'c'): 5,
#          ('it', "'s"): 5,
#          ('been', 'selected'): 5,
#          ('only', 'had'): 5,
#          ('update', 'co'): 5,
#          ('co', 'free'): 5,
#          ('and', 'send'): 5,
#          ('the', 'next'): 5,
#          ('you', 'will'): 5,
#          ('etc', 'all'): 5,
#          ('miss', 'out'): 5,
#          ('free', 'ringtone'): 5,
#          ('you', 'last'): 5,
#          ('last', 'weekends'): 5,
#          ('weekends', 'draw'): 5,
#          ('are', 'winner'): 5,
#          ('or', '4'): 5,
#          ('4', 'holiday'): 5,
#          ('was', 'awarded'): 5,
#          ('todays', 'voda'): 5,
#          ('voda', 'numbers'): 5,
#          ('match', 'please'): 5,
#          ('call', '08712300220'): 5,
#          ('08712300220', 'quoting'): 5,
#          ('quoting', 'claim'): 5,
#          ('standard', 'rates'): 5,
#          ('sunshine', 'quiz'): 5,
#          ('sony', 'dvd'): 5,
#          ('sent', 'direct'): 5,
#          ('be', 'her'): 5,
#          ('her', 'friend'): 5,
#          ('see', 'her'): 5,
#          ('on', 'the'): 5,
#          ('2', 'find'): 5,
#          ('87066', 'tncs'): 5,
#          ('video', 'handset'): 5,
#          ('handset', '750'): 5,
#          ('mins', 'unlimited'): 5,
#          ('unlimited', 'text'): 5,
#          ('camera', 'phone'): 5,
#          ('win', '£200'): 5,
#          ('send', 'go'): 5,
#          ('150p/msg', 'rcvd'): 5,
#          ('cash', 'to'): 5,
#          ('150p/msg', 'cc'): 5,
#          ('free', 'bluetooth'): 5,
#          ('latest', 'camera'): 5,
#          ('phones', '4'): 5,
#          ('entry', 'into'): 5,
#          ('now', '18'): 5,
#          ('cost', '150ppm'): 5,
#          ('help', 'call'): 5,
#          ('text', 'back'): 5,
#          ('now', 'on'): 5,
#          ('text', 'messages'): 5,
#          ('latest', 'nokia'): 5,
#          ('ipod', 'mp3'): 5,
#          ('mp3', 'player'): 5,
#          ('collect', 'to'): 5,
#          ('our', '2nd'): 5,
#          ('savamob', 'member'): 5,
#          ('member', 'offers'): 5,
#          ('£3.00', 'sub'): 5,
#          ('sub', '16'): 5,
#          ('now', 'or'): 5,
#          ('reply', 'for'): 5,
#          ('for', 'ur'): 5,
#          ('ur', 'chance'): 5,
#          ('win', '£250'): 5,
#          ('free', '2'): 5,
#          ('name', 'to'): 5,
#          ('to', 'http'): 5,
#          ('immediately', 'as'): 5,
#          ('as', 'there'): 5,
#          ('an', 'urgent'): 5,
#          ('urgent', 'message'): 5,
#          ('message', 'waiting'): 5,
#          ('cost', '10p'): 5,
#          ('mobile', 'content'): 5,
#          ('awarded', 'either'): 5,
#          ('cd', 'gift'): 5,
#          ('text', 'credits'): 5,
#          ('credits', 'pls'): 5,
#          ('unsubscribe', 'with'): 5,
#          ('with', 'stop'): 5,
#          ('stop', 'no'): 5,
#          ('no', 'extra'): 5,
#          ('extra', 'charge'): 5,
#          ('8007', 'for'): 5,
#          ('mins', 'half'): 5,
#          ('your', 'prize'): 5,
#          ('or', '£10,000'): 5,
#          ('£10,000', 'cash'): 5,
#          ('cc', '08718720201'): 5,
#          ('congrats', '2'): 5,
#          ('2', 'mobile'): 5,
#          ('mobile', '3g'): 5,
#          ('3g', 'videophones'): 5,
#          ('videophones', 'r'): 5,
#          ('r', 'yours'): 5,
#          ('now', 'videochat'): 5,
#          ('videochat', 'wid'): 5,
#          ('mates', 'play'): 5,
#          ('play', 'java'): 5,
#          ('java', 'games'): 5,
#          ('games', 'dload'): 5,
#          ('music', 'noline'): 5,
#          ('noline', 'rentl'): 5,
#          ('now', 'txt'): 5,
#          ('in', 'your'): 5,
#          ('guess', 'who'): 5,
#          ('all', 'will'): 5,
#          ('be', 'revealed'): 5,
#          ('u', "'ve"): 5,
#          ('been', 'invited'): 5,
#          ('gift', 'voucher'): 5,
#          ('your', 'lucky'): 5,
#          ('fantastic', 'surprise'): 5,
#          ('surprise', 'awaiting'): 5,
#          ('won', '£2,000'): 5,
#          ('with', 'free'): 5,
#          ('no', '1'): 5,
#          ('1st', 'tone'): 5,
#          ('tone', 'free'): 5,
#          ('network', 'operator'): 5,
#          ('rates', 'apply'): 5,
#          ('hot', 'live'): 5,
#          ('live', 'fantasies'): 5,
#          ('to', 'reach'): 5,
#          ('reach', 'you'): 5,
#          ('0870', 'is'): 5,
#          ('is', 'national'): 5,
#          ('won', 'nokia'): 5,
#          ('is', 'what'): 5,
#          ('you', 'get'): 5,
#          ('get', 'when'): 5,
#          ('win', 'our'): 5,
#          ('our', 'free'): 5,
#          ('free', 'auction'): 5,
#          ('auction', 'to'): 5,
#          ('to', 'take'): 5,
#          ('part', 'send'): 5,
#          ('send', 'nokia'): 5,
#          ('now', 'hg/suite342/2lands'): 5,
#          ('free', 'msg'): 5,
#          ('computer', 'has'): 5,
#          ('an', 'ipod'): 5,
#          ('mobile', 'or'): 5,
#          ('the', 'official'): 5,
#          ('ip4', '5we'): 5,
#          ('should', 'your'): 5,
#          ('tone', 'not'): 5,
#          ('not', 'arrive'): 5,
#          ('arrive', 'please'): 5,
#          ('call', 'customer'): 5,
#          ('minute', 'bt-national-rate'): 5,
#          ('plus', 'free'): 5,
#          ('welcome', 'to'): 5,
#          ('nokia', '3510i'): 5,
#          ('3510i', 'colour'): 5,
#          ('colour', 'phone'): 5,
#          ('free', 'minutes'): 5,
#          ('minutes', 'to'): 5,
#          ('to', 'any'): 5,
#          ('any', 'mobile'): 5,
#          ('mobile', '100'): 5,
#          ('get', 'your'): 5,
#          ('wkly', 'comp'): 4,
#          ('cup', 'final'): 4,
#          ('to', '87121'): 4,
#          ('week', "'s"): 4,
#          ('mobile', '11'): 4,
#          ('to', 'use'): 4,
#          ('no', 'you'): 4,
#          ('to', 'call'): 4,
#          ('sms', 'ac'): 4,
#          ('and', 'the'): 4,
#          ('for', '2'): 4,
#          ('now', 'c'): 4,
#          ('or', '£1000'): 4,
#          ('on', '0800'): 4,
#          ('is', 'waiting'): 4,
#          ('text', 'the'): 4,
#          ("''", 'to'): 4,
#          ('won', '£1000'): 4,
#          ('£1000', 'prize'): 4,
#          ('150ppm', 'you'): 4,
#          ('winner', 'u'): 4,
#          ('selected', '2'): 4,
#          ('holiday', 'flights'): 4,
#          ('flights', 'inc'): 4,
#          ('inc', 'speak'): 4,
#          ('operator', '2'): 4,
#          ('your', '2004'): 4,
#          ('2004', 'account'): 4,
#          ('shows', '786'): 4,
#          ('786', 'unredeemed'): 4,
#          ('points', 'to'): 4,
#          ('have', 'match'): 4,
#          ('rates', 'app'): 4,
#          ('quiz', 'wkly'): 4,
#          ('wkly', 'q'): 4,
#          ('q', 'win'): 4,
#          ('win', 'top'): 4,
#          ('top', 'sony'): 4,
#          ('dvd', 'player'): 4,
#          ('player', 'if'): 4,
#          ('know', 'which'): 4,
#          ('which', 'country'): 4,
#          ('txt', 'ansr'): 4,
#          ('ansr', 'to'): 4,
#          ('to', '82277'): 4,
#          ('82277', '£1.50'): 4,
#          ('£1.50', 'tyrone'): 4,
#          ('get', 'laid'): 4,
#          ('want', 'real'): 4,
#          ('locations', 'sent'): 4,
#          ('direct', '2'): 4,
#          ('largest', 'dogging'): 4,
#          ('dogging', 'network'): 4,
#          ('from', 'the'): 4,
#          ('now', 'to'): 4,
#          ('u', 'do'): 4,
#          ('on', 'freephone'): 4,
#          ('freephone', '0808'): 4,
#          ('0808', '145'): 4,
#          ('145', '4742'): 4,
#          ('4742', 'between'): 4,
#          ('between', '9am-11pm'): 4,
#          ('9am-11pm', 'as'): 4,
#          ('vouchers', 'or'): 4,
#          ('wkly', 'draw'): 4,
#          ('tncs', 'www.ldew.com1win150ppmx3age16'): 4,
#          ('of', 'video'): 4,
#          ('want', 'to'): 4,
#          ('stop', 'txt'): 4,
#          ('message', 'is'): 4,
#          ('you', 'may'): 4,
#          ('free', 'camera'): 4,
#          ('selection', 'of'): 4,
#          ('december', 'only'): 4,
#          ('mobile', '11mths+'): 4,
#          ('11mths+', 'you'): 4,
#          ('are', 'entitled'): 4,
#          ('camera', 'mobile'): 4,
#          ('on', '08002986906'): 4,
#          ('now', '150p/msg'): 4,
#          ('hg/suite342/2lands', 'row/w1j6hl'): 4,
#          ('motorola', 'sonyericsson'): 4,
#          ('sonyericsson', 'nokia'): 4,
#          ('txt', 'on'): 4,
#          ('order', 'reference'): 4,
#          ('price', 'orange'): 4,
#          ('orange', 'line'): 4,
#          ('into', 'our'): 4,
#          ('our', '£250'): 4,
#          ('£250', 'weekly'): 4,
#          ('18', 'c'): 4,
#          ('service', 'and'): 4,
#          ('video', 'camera'): 4,
#          ('for', 'any'): 4,
#          ('any', 'purpose'): 4,
#          ('tenants', 'welcome'): 4,
#          ('have', 'you'): 4,
#          ('back', "'help"): 4,
#          ('for', 'terms'): 4,
#          ('18', 'only'): 4,
#          ('are', 'guaranteed'): 4,
#          ('guaranteed', 'the'): 4,
#          ('nokia', 'phone'): 4,
#          ('phone', '40gb'): 4,
#          ('player', 'or'): 4,
#          ('or', '£500'): 4,
#          ('£500', 'prize'): 4,
#          ('prize', 'txt'): 4,
#          ('word', 'collect'): 4,
#          ('mins', '150'): 4,
#          ('shop', 'to'): 4,
#          ('have', 'an'): 4,
#          ('an', 'important'): 4,
#          ('important', 'customer'): 4,
#          ('call', 'freephone'): 4,
#          ('freephone', '0800'): 4,
#          ('0800', '542'): 4,
#          ('latest', 'news'): 4,
#          ('news', 'and'): 4,
#          ('ending', 'with'): 4,
#          ('your', 'number'): 4,
#          ('claim', 'this'): 4,
#          ('weeks', 'offer'): 4,
#          ('offer', 'at'): 4,
#          ('text', 'me'): 4,
#          ('forwarded', 'from'): 4,
#          ('between', '10am-7pm'): 4,
#          ('urgent', 'this'): 4,
#          ('claim', 'yr'): 4,
#          ('yr', 'prize'): 4,
#          ('customer', 'loyalty'): 4,
#          ('loyalty', 'offer'): 4,
#          ('offer', 'the'): 4,
#          ('mobile', 'from'): 4,
#          ('only', '£10'): 4,
#          ('£10', 'at'): 4,
#          ('at', 'txtauction'): 4,
#          ('txtauction', 'txt'): 4,
#          ('word', 'start'): 4,
#          ('start', 'to'): 4,
#          ('get', 'yours'): 4,
#          ('yours', 'now'): 4,
#          ('now', '4t'): 4,
#          ('spree', 'every'): 4,
#          ('store', 'to'): 4,
#          ('chance', 'claim'): 4,
#          ('vouchers', 'today'): 4,
#          ('today', 'text'): 4,
#          ('cs', 'savamob'): 4,
#          ('savamob', 'pobox84'): 4,
#          ('pobox84', 'm263uz'): 4,
#          ('m263uz', '£3.00'): 4,
#          ('either', '£500'): 4,
#          ('vouchers', 'free'): 4,
#          ('our', '£100'): 4,
#          ('pls', 'goto'): 4,
#          ('goto', 'www.comuk.net'): 4,
#          ('www.comuk.net', 'login='): 4,
#          ('3qxj9', 'unsubscribe'): 4,
#          ('charge', 'help'): 4,
#          ('or', 'poly'): 4,
#          ('for', 'polys'): 4,
#          ('to', '80062'): 4,
#          ('urgent', 'call'): 4,
#          ('ibiza', 'holiday'): 4,
#          ('cs', 'po'): 4,
#          ('voucher', 'call'): 4,
#          ('all', 'the'): 4,
#          ('gay', 'chat'): 4,
#          ('to', 'give'): 4,
#          ('cs', 'box'): 4,
#          ('150ppm', '18+'): 4,
#          ('8007', 'get'): 4,
#          ('w45wq', 'norm150p/tone'): 4,
#          ('norm150p/tone', '16+'): 4,
#          ('and', 'get'): 4,
#          ('your', 'area'): 4,
#          ('reply', 'date'): 4,
#          ('someone', 'u'): 4,
#          ('know', 'has'): 4,
#          ('has', 'asked'): 4,
#          ('asked', 'our'): 4,
#          ('service', '2'): 4,
#          ('you', 'cant'): 4,
#          ('cant', 'guess'): 4,
#          ('who', 'call'): 4,
#          ('invited', 'to'): 4,
#          ('to', 'xchat'): 4,
#          ('xchat', 'this'): 4,
#          ('u', 'txt'): 4,
#          ('4', '£100'): 4,
#          ('will', 'b'): 4,
#          ('user', 'today'): 4,
#          ('day', '2'): 4,
#          ('awaiting', 'you'): 4,
#          ('you', 'do'): 4,
#          ('just', 'send'): 4,
#          ('i', 'do'): 4,
#          ('and', 'u'): 4,
#          ('send', 'chat'): 4,
#          ('let', "'s"): 4,
#          ('ldn', '18'): 4,
#          ('2', 'this'): 4,
#          ('up', 'ur'): 4,
#          ('then', 'every'): 4,
#          ('free', 'so'): 4,
#          ('so', 'get'): 4,
#          ('get', 'txtin'): 4,
#          ('txtin', 'now'): 4,
#          ('ur', 'friends'): 4,
#          ('friends', '150p/tone'): 4,
#          ('150p/tone', '16'): 4,
#          ('16', 'reply'): 4,
#          ('hl', '4info'): 4,
#          ('with', 'your'): 4,
#          ('phone', 'now'): 4,
#          ('tone', 'reply'): 4,
#          ('www.ringtones.co.uk', 'the'): 4,
#          ('the', 'original'): 4,
#          ('original', 'best'): 4,
#          ('best', 'tones'): 4,
#          ('tones', '3gbp'): 4,
#          ('3gbp', 'network'): 4,
#          ('operator', 'rates'): 4,
#          ('mins', 'double'): 4,
#          ('double', 'txt'): 4,
#          ('1/2', 'price'): 4,
#          ('150p/msgrcvdhg/suite342/2lands/row/w1j6hl', 'ldn'): 4,
#          ('txt', 'pod'): 4,
#          ('pod', 'to'): 4,
#          ('just', 'reply'): 4,
#          ('2', 'join'): 4,
#          ('optout', 'txt'): 4,
#          ('2', 'c'): 4,
#          ('on', '02/06/03'): 4,
#          ('02/06/03', 'this'): 4,
#          ('brand', 'new'): 4,
#          ('nokia', '7250i'): 4,
#          ('7250i', 'this'): 4,
#          ('you', 'win'): 4,
#          ('hg/suite342/2lands', 'row/w1jhl'): 4,
#          ('row/w1jhl', '16+'): 4,
#          ('free', 'texts'): 4,
#          ('they', 'are'): 4,
#          ('u', 'like'): 4,
#          ('just', '60p/min'): 4,
#          ('hi', 'this'): 4,
#          ('operator', 'to'): 4,
#          ('08001950382', 'or'): 4,
#          ('tried', '2'): 4,
#          ('pound', 'prize'): 4,
#          ('easy', 'call'): 4,
#          ('£5000', 'cash'): 4,
#          ('for', 'details'): 4,
#          ('stop', '2'): 4,
#          ('there', "'s"): 4,
#          ('well', 'done'): 4,
#          ('to', '87239'): 4,
#          ('week', 'starting'): 4,
#          ('starting', 'now'): 4,
#          ('poly', 'ringtone'): 4,
#          ('ringtone', 'or'): 4,
#          ('or', 'colour'): 4,
#          ('colour', 'flag'): 4,
#          ('flag', 'on'): 4,
#          ('on', 'yer'): 4,
#          ('yer', 'mobile'): 4,
#          ('text', 'tone'): 4,
#          ('tone', 'or'): 4,
#          ('or', 'flag'): 4,
#          ('flag', 'to'): 4,
#          ('txt', 'eng'): 4,
#          ('eng', 'stop'): 4,
#          ('stop', 'box39822'): 4,
#          ('box39822', 'w111wx'): 4,
#          ('w111wx', '£1.50'): 4,
#          ('sms', 'services'): 4,
#          ('services', 'for'): 4,
#          ('your', 'inclusive'): 4,
#          ('inclusive', 'text'): 4,
#          ('sae', 'tc'): 4,
#          ('tc', 'pobox334'): 4,
#          ('new', 'message'): 4,
#          ('call', 'back'): 4,
#          ('back', 'on'): 4,
#          ('thanks', 'to'): 4,
#          ('xmas', 'prize'): 4,
#          ('won', '£2000'): 4,
#          ('tone', 'txt'): 4,
#          ('wid', 'ur'): 4,
#          ('rentl', 'bx420'): 4,
#          ('bx420', 'ip4'): 4,
#          ('date', 'now'): 4,
#          ('you', "'ve"): 4,
#          ('msg', 'is'): 4,
#          ('camera', 'you'): 4,
#          ('call', '09061221066'): 4,
#          ('09061221066', 'fromm'): 4,
#          ('fromm', 'landline'): 4,
#          ('within', '28'): 4,
#          ('28', 'days'): 4,
#          ('are', 'being'): 4,
#          ('by', 'someone'): 4,
#          ('yes', 'for'): 4,
#          ('text', 'free'): 4,
#          ('our', 'computer'): 4,
#          ('picked', 'you'): 4,
#          ('freemsg', 'hey'): 3,
#          ('up', 'for'): 3,
#          ('winner', 'as'): 3,
#          ('valued', 'network'): 3,
#          ('network', 'customer'): 3,
#          ('reward', 'to'): 3,
#          ('hours', 'only'): 3,
#          ('week', 'free'): 3,
#          ('claim', 'to'): 3,
#          ('txt', 'ur'): 3,
#          ('call', 'you'): 3,
#          ('our', 'sms'): 3,
#          ('sms', 'for'): 3,
#          ('free', 'nokia'): 3,
#          ('now', '08000930705'): 3,
#          ('reply', 'end'): 3,
#          ('congrats', '1'): 3,
#          ('1', 'year'): 3,
#          ('year', 'special'): 3,
#          ('special', 'cinema'): 3,
#          ('cinema', 'pass'): 3,
#          ('pass', 'for'): 3,
#          ('2', 'is'): 3,
#          ('is', 'yours'): 3,
#          ('call', '09061209465'): 3,
#          ('09061209465', 'now'): 3,
#          ('c', 'suprman'): 3,
#          ('suprman', 'v'): 3,
#          ('v', 'matrix3'): 3,
#          ('matrix3', 'starwars3'): 3,
#          ('starwars3', 'etc'): 3,
#          ('all', '4'): 3,
#          ('free', 'bx420-ip4-5we'): 3,
#          ('bx420-ip4-5we', '150pm'): 3,
#          ('150pm', 'dont'): 3,
#          ('valued', 'customer'): 3,
#          ('customer', 'i'): 3,
#          ('i', 'pleased'): 3,
#          ('pleased', 'to'): 3,
#          ('to', 'advise'): 3,
#          ('advise', 'you'): 3,
#          ('you', 'that'): 3,
#          ('that', 'following'): 3,
#          ('following', 'recent'): 3,
#          ('recent', 'review'): 3,
#          ('review', 'of'): 3,
#          ('of', 'your'): 3,
#          ('mob', 'no'): 3,
#          ('with', '£1500'): 3,
#          ('£1500', 'bonus'): 3,
#          ('bonus', 'prize'): 3,
#          ('urgent', 'ur'): 3,
#          ...})
